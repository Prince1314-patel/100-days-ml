# %%
import pandas as pd
import numpy as np
from mlxtend.plotting import plot_decision_regions

# %%
#!pip install mlxtend
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting mlxtend
#   Downloading mlxtend-0.23.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\princ\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlxtend) (1.13.0)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\princ\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlxtend) (1.26.4)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\princ\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlxtend) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\princ\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\princ\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlxtend) (3.8.4)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\princ\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\princ\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib>=3.0.0->mlxtend) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\princ\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\princ\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib>=3.0.0->mlxtend) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\princ\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\princ\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib>=3.0.0->mlxtend) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\princ\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib>=3.0.0->mlxtend) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\princ\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib>=3.0.0->mlxtend) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\princ\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\princ\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas>=0.24.2->mlxtend) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\princ\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas>=0.24.2->mlxtend) (2024.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\princ\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn>=1.0.2->mlxtend) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\princ\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Downloading mlxtend-0.23.1-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.4 MB 660.6 kB/s eta 0:00:03
#    --- ------------------------------------ 0.1/1.4 MB 1.1 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.2/1.4 MB 1.4 MB/s eta 0:00:01
#    ------ --------------------------------- 0.2/1.4 MB 1.4 MB/s eta 0:00:01
#    --------- ------------------------------ 0.3/1.4 MB 1.6 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.4/1.4 MB 1.5 MB/s eta 0:00:01
#    ------------ --------------------------- 0.5/1.4 MB 1.5 MB/s eta 0:00:01
#    --------------- ------------------------ 0.6/1.4 MB 1.6 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.6/1.4 MB 1.6 MB/s eta 0:00:01
#    -------------------- ------------------- 0.7/1.4 MB 1.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 0.8/1.4 MB 1.7 MB/s eta 0:00:01
#    ------------------------ --------------- 0.9/1.4 MB 1.7 MB/s eta 0:00:01
#    -------------------------- ------------- 1.0/1.4 MB 1.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.0/1.4 MB 1.7 MB/s eta 0:00:01
#    ------------------------------- -------- 1.2/1.4 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.2/1.4 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------- -- 1.4/1.4 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  1.4/1.4 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 1.8 MB/s eta 0:00:00
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.23.1

# %%
df = pd.DataFrame()

# %%
df['X1'] = [1,2,3,4,5,6,6,7,9,9]
df['X2'] = [5,3,6,8,1,9,5,8,9,2]
df['label'] = [1,1,0,1,0,1,0,1,0,0]

# %%
df
# Out:
#    X1  X2  label
# 0   1   5      1
# 1   2   3      1
# 2   3   6      0
# 3   4   8      1
# 4   5   1      0
# 5   6   9      1
# 6   6   5      0
# 7   7   8      1
# 8   9   9      0
# 9   9   2      0

# %%
import seaborn as sns
sns.scatterplot(x=df['X1'],y=df['X2'],hue=df['label'])
# Out:
# <Axes: xlabel='X1', ylabel='X2'>

# %%
df['weights'] = 1/df.shape[0]

# %%
df
# Out:
#    X1  X2  label  weights
# 0   1   5      1      0.1
# 1   2   3      1      0.1
# 2   3   6      0      0.1
# 3   4   8      1      0.1
# 4   5   1      0      0.1
# 5   6   9      1      0.1
# 6   6   5      0      0.1
# 7   7   8      1      0.1
# 8   9   9      0      0.1
# 9   9   2      0      0.1

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt1 = DecisionTreeClassifier(max_depth=1)

# %%
X = df.iloc[:,0:2].values
y = df.iloc[:,2].values

# %%
#step-2 train the 1st model
dt1.fit(X,y)
# Out:
# DecisionTreeClassifier(max_depth=1)

# %%
from sklearn.tree import plot_tree
plot_tree(dt1)
# Out:
# [Text(0.5, 0.75, 'x[0] <= 2.5\ngini = 0.5\nsamples = 10\nvalue = [5, 5]'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.75, 0.25, 'gini = 0.469\nsamples = 8\nvalue = [5, 3]')]

# %%
plot_decision_regions(X,y,clf=dt1,legend=2)
# Out:
# <Axes: >

# %%
df['y_pred'] = dt1.predict(X)

# %%
df
# Out:
#    X1  X2  label  weights  y_pred
# 0   1   5      1      0.1       1
# 1   2   3      1      0.1       1
# 2   3   6      0      0.1       0
# 3   4   8      1      0.1       0
# 4   5   1      0      0.1       0
# 5   6   9      1      0.1       0
# 6   6   5      0      0.1       0
# 7   7   8      1      0.1       0
# 8   9   9      0      0.1       0
# 9   9   2      0      0.1       0

# %%
def calculate_model_weight(error):
    return 0.5*np.log((1-error)/error)

# %%
# Step-3 calculate model weight
alpha1 = calculate_model_weight(0.3)
alpha1
# Out:
# 0.42364893019360184

# %%
# Step-4 update weights
9def update_row_weights(row,alpha=0.423):
    if row['label'] == row['y_pred']:
        return row['weights'] * np.exp(-alpha)
    else:
        return row['weights'] * np.exp(alpha)

# %%
df['updated_weights'] = df.apply(update_row_weights,axis=1)

# %%
df
# Out:
#    X1  X2  label  weights  y_pred  updated_weights
# 0   1   5      1      0.1       1         0.065508
# 1   2   3      1      0.1       1         0.065508
# 2   3   6      0      0.1       0         0.065508
# 3   4   8      1      0.1       0         0.152653
# 4   5   1      0      0.1       0         0.065508
# 5   6   9      1      0.1       0         0.152653
# 6   6   5      0      0.1       0         0.065508
# 7   7   8      1      0.1       0         0.152653
# 8   9   9      0      0.1       0         0.065508
# 9   9   2      0      0.1       0         0.065508

# %%
df['updated_weights'].sum()
# Out:
# 0.9165153319682015

# %%
df['normalised_weights'] = df['updated_weights']/df['updated_weights'].sum()

# %%
df
# Out:
#    X1  X2  label  weights  y_pred  updated_weights  normalised_weights
# 0   1   5      1      0.1       1         0.065508            0.071475
# 1   2   3      1      0.1       1         0.065508            0.071475
# 2   3   6      0      0.1       0         0.065508            0.071475
# 3   4   8      1      0.1       0         0.152653            0.166559
# 4   5   1      0      0.1       0         0.065508            0.071475
# 5   6   9      1      0.1       0         0.152653            0.166559
# 6   6   5      0      0.1       0         0.065508            0.071475
# 7   7   8      1      0.1       0         0.152653            0.166559
# 8   9   9      0      0.1       0         0.065508            0.071475
# 9   9   2      0      0.1       0         0.065508            0.071475

# %%
df['cumsum_upper'] = np.cumsum(df['normalised_weights'])

# %%
df['cumsum_lower'] = df['cumsum_upper'] - df['normalised_weights']

# %%
df[['X1','X2','label','weights','y_pred','updated_weights','cumsum_lower','cumsum_upper']]
# Out:
#    X1  X2  label  weights  y_pred  updated_weights  cumsum_lower  cumsum_upper
# 0   1   5      1      0.1       1         0.065508      0.000000      0.071475
# 1   2   3      1      0.1       1         0.065508      0.071475      0.142950
# 2   3   6      0      0.1       0         0.065508      0.142950      0.214425
# 3   4   8      1      0.1       0         0.152653      0.214425      0.380983
# 4   5   1      0      0.1       0         0.065508      0.380983      0.452458
# 5   6   9      1      0.1       0         0.152653      0.452458      0.619017
# 6   6   5      0      0.1       0         0.065508      0.619017      0.690492
# 7   7   8      1      0.1       0         0.152653      0.690492      0.857050
# 8   9   9      0      0.1       0         0.065508      0.857050      0.928525
# 9   9   2      0      0.1       0         0.065508      0.928525      1.000000

# %%
def create_new_dataset(df):

  indices = []

  for i in range(df.shape[0]):
    a = np.random.random()
    for index,row in df.iterrows():
      if row['cumsum_upper'] > a and a > row['cumsum_lower']:
        indices.append(index)
  return indices

# %%
index_values = create_new_dataset(df)

index_values
# Out:
# [7, 5, 4, 2, 7, 5, 1, 7, 2, 6]

# %%
second_df = df.iloc[index_values,[0,1,2,3]]
     

second_df
# Out:
#    X1  X2  label  weights
# 7   7   8      1      0.1
# 5   6   9      1      0.1
# 4   5   1      0      0.1
# 2   3   6      0      0.1
# 7   7   8      1      0.1
# 5   6   9      1      0.1
# 1   2   3      1      0.1
# 7   7   8      1      0.1
# 2   3   6      0      0.1
# 6   6   5      0      0.1

# %%
dt2 = DecisionTreeClassifier(max_depth=1)
     

X = second_df.iloc[:,0:2].values
y = second_df.iloc[:,2].values
     

dt2.fit(X,y)
# Out:
# DecisionTreeClassifier(max_depth=1)

# %%
plot_tree(dt2)
# Out:
# [Text(0.5, 0.75, 'x[1] <= 7.0\ngini = 0.48\nsamples = 10\nvalue = [4, 6]'),
#  Text(0.25, 0.25, 'gini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]')]

# %%
plot_decision_regions(X, y, clf=dt2, legend=2)
# Out:
# <Axes: >

# %%
second_df['y_pred'] = dt2.predict(X)

# %%
second_df
# Out:
#    X1  X2  label  weights  y_pred
# 7   7   8      1      0.1       1
# 5   6   9      1      0.1       1
# 4   5   1      0      0.1       0
# 2   3   6      0      0.1       0
# 7   7   8      1      0.1       1
# 5   6   9      1      0.1       1
# 1   2   3      1      0.1       0
# 7   7   8      1      0.1       1
# 2   3   6      0      0.1       0
# 6   6   5      0      0.1       0

# %%
alpha2 = calculate_model_weight(0.1)

# %%
alpha2
# Out:
# 1.0986122886681098

# %%
# Step 4 - Update weights
def update_row_weights(row,alpha=1.09):
  if row['label'] == row['y_pred']:
    return row['weights'] * np.exp(-alpha)
  else:
    return row['weights'] * np.exp(alpha)

# %%
second_df['updated_weights'] = second_df.apply(update_row_weights,axis=1)
     

second_df
# Out:
#    X1  X2  label  weights  y_pred  updated_weights
# 7   7   8      1      0.1       1         0.033622
# 5   6   9      1      0.1       1         0.033622
# 4   5   1      0      0.1       0         0.033622
# 2   3   6      0      0.1       0         0.033622
# 7   7   8      1      0.1       1         0.033622
# 5   6   9      1      0.1       1         0.033622
# 1   2   3      1      0.1       0         0.297427
# 7   7   8      1      0.1       1         0.033622
# 2   3   6      0      0.1       0         0.033622
# 6   6   5      0      0.1       0         0.033622

# %%
second_df['nomalized_weights'] = second_df['updated_weights']/second_df['updated_weights'].sum()
     

second_df
# Out:
#    X1  X2  label  weights  y_pred  updated_weights  nomalized_weights
# 7   7   8      1      0.1       1         0.033622           0.056034
# 5   6   9      1      0.1       1         0.033622           0.056034
# 4   5   1      0      0.1       0         0.033622           0.056034
# 2   3   6      0      0.1       0         0.033622           0.056034
# 7   7   8      1      0.1       1         0.033622           0.056034
# 5   6   9      1      0.1       1         0.033622           0.056034
# 1   2   3      1      0.1       0         0.297427           0.495694
# 7   7   8      1      0.1       1         0.033622           0.056034
# 2   3   6      0      0.1       0         0.033622           0.056034
# 6   6   5      0      0.1       0         0.033622           0.056034

# %%
second_df['nomalized_weights'].sum()


second_df['cumsum_upper'] = np.cumsum(second_df['nomalized_weights'])
     

second_df['cumsum_lower'] = second_df['cumsum_upper'] - second_df['nomalized_weights']
     

second_df[['X1','X2','label','weights','y_pred','nomalized_weights','cumsum_lower','cumsum_upper']]
# Out:
#    X1  X2  label  weights  y_pred  nomalized_weights  cumsum_lower  \
# 7   7   8      1      0.1       1           0.056034      0.000000
# 5   6   9      1      0.1       1           0.056034      0.056034
# 4   5   1      0      0.1       0           0.056034      0.112068
# 2   3   6      0      0.1       0           0.056034      0.168102
# 7   7   8      1      0.1       1           0.056034      0.224136
# 5   6   9      1      0.1       1           0.056034      0.280170
# 1   2   3      1      0.1       0           0.495694      0.336204
# 7   7   8      1      0.1       1           0.056034      0.831898
# 2   3   6      0      0.1       0           0.056034      0.887932
# 6   6   5      0      0.1       0           0.056034      0.943966
#
#    cumsum_upper
# 7      0.056034
# 5      0.112068
# 4      0.168102
# 2      0.224136
# 7      0.280170
# 5      0.336204
# 1      0.831898
# 7      0.887932
# 2      0.943966
# 6      1.000000

# %%
index_values = create_new_dataset(second_df)
     

third_df = second_df.iloc[index_values,[0,1,2,3]]
     

third_df
# Out:
#    X1  X2  label  weights
# 1   2   3      1      0.1
# 7   7   8      1      0.1
# 5   6   9      1      0.1
# 4   5   1      0      0.1
# 5   6   9      1      0.1
# 5   6   9      1      0.1
# 7   7   8      1      0.1
# 4   5   1      0      0.1
# 1   2   3      1      0.1
# 5   6   9      1      0.1

# %%
dt3 = DecisionTreeClassifier(max_depth=1)

X = second_df.iloc[:,0:2].values
y = second_df.iloc[:,2].values

dt3.fit(X,y)
# Out:
# DecisionTreeClassifier(max_depth=1)

# %%
plot_decision_regions(X, y, clf=dt3, legend=2)
# Out:
# <Axes: >

# %%
third_df['y_pred'] = dt3.predict(X)
     

third_df
# Out:
#    X1  X2  label  weights  y_pred
# 1   2   3      1      0.1       1
# 7   7   8      1      0.1       1
# 5   6   9      1      0.1       0
# 4   5   1      0      0.1       0
# 5   6   9      1      0.1       1
# 5   6   9      1      0.1       1
# 7   7   8      1      0.1       0
# 4   5   1      0      0.1       1
# 1   2   3      1      0.1       0
# 5   6   9      1      0.1       0

# %%
alpha3 = calculate_model_weight(0.7)
alpha3
     
-0.4236489301936017

print(alpha1,alpha2,alpha3)
# Out:
# 0.42364893019360184 1.0986122886681098 -0.4236489301936017

# %% [markdown]
# Prediction

# %%
query = np.array([1,5]).reshape(1,2)
dt1.predict(query)
# Out:
# array([1], dtype=int64)

# %%
dt2.predict(query)
# Out:
# array([0], dtype=int64)

# %%
dt3.predict(query)
# Out:
# array([0], dtype=int64)

# %%
alpha1*1 + alpha2*(1) + alpha3*(1)
# Out:
# 1.09861228866811

# %%
np.sign(1.09)
# Out:
# 1.0

# %%
query = np.array([9,9]).reshape(1,2)
dt1.predict(query)
# Out:
# array([0], dtype=int64)

# %%
dt2.predict(query)
# Out:
# array([1], dtype=int64)

# %%
dt3.predict(query)
# Out:
# array([1], dtype=int64)

# %%
alpha1*(1) + alpha2*(-1) + alpha3*(-1)
# Out:
# -0.2513144282809062

# %%
np.sign(-0.25)
# Out:
# -1.0
